# %%
from ultralytics import YOLO
import cv2

# Load the YOLO model (use a pre-trained model for object detection)
model = YOLO('yolov8s.pt')  # 'yolov8s.pt' is a small model with better accuracy compared to 'yolov8n.pt'.

# Open the webcam feed
cap = cv2.VideoCapture(0)  # Use 0 for the default camera, or replace with the camera index if multiple cameras are present.

# Check if the webcam is opened
if not cap.isOpened():
    print("Error: Could not open the webcam.")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read the frame.")
        break

    # Perform detection on the current frame
    results = model(frame)

    # Get detection results
    human_count = 0
    for result in results[0].boxes:
        class_id = int(result.cls)  # Get the class ID of the detected object
        confidence = result.conf.item()  # Convert tensor to a Python float
        x1, y1, x2, y2 = map(int, result.xyxy[0])  # Extract bounding box coordinates

        if class_id == 0:  # Class 0 corresponds to 'person' in the COCO dataset
            human_count += 1
            # Draw bounding box and label for humans
            cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
            cv2.putText(frame, f'Human ({confidence:.2f})', (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)

    # Display human count on the frame
    cv2.putText(frame, f'Humans detected: {human_count}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)

    # Print human count to the console
    print(f"Humans detected: {human_count}")

    # Show the frame with detection results
    cv2.imshow("Human Detection", frame)

    # Exit the loop when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 572.8ms
# Speed: 8.0ms preprocess, 572.8ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 1 person, 601.4ms
# Speed: 0.0ms preprocess, 601.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 1 person, 1 chair, 509.8ms
# Speed: 5.6ms preprocess, 509.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 2 persons, 1 chair, 515.0ms
# Speed: 9.1ms preprocess, 515.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 2 persons, 538.2ms
# Speed: 5.6ms preprocess, 538.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 2 persons, 1 chair, 581.5ms
# Speed: 7.0ms preprocess, 581.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 1 person, 1 cell phone, 529.4ms
# Speed: 24.0ms preprocess, 529.4ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 1 person, 526.0ms
# Speed: 7.6ms preprocess, 526.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 2 persons, 1 chair, 525.3ms
# Speed: 6.0ms preprocess, 525.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 1 person, 1 chair, 512.4ms
# Speed: 6.1ms preprocess, 512.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 1 person, 497.6ms
# Speed: 9.1ms preprocess, 497.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 2 persons, 496.0ms
# Speed: 6.0ms preprocess, 496.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 2 persons, 486.0ms
# Speed: 3.1ms preprocess, 486.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 1 person, 1 chair, 500.0ms
# Speed: 8.1ms preprocess, 500.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 2 persons, 488.2ms
# Speed: 0.0ms preprocess, 488.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 (no detections), 487.7ms
# Speed: 9.1ms preprocess, 487.7ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 0
#
# 0: 480x640 1 person, 483.5ms
# Speed: 8.6ms preprocess, 483.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 1 person, 1 kite, 497.9ms
# Speed: 7.7ms preprocess, 497.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 2 persons, 505.8ms
# Speed: 5.6ms preprocess, 505.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 2 persons, 507.9ms
# Speed: 8.0ms preprocess, 507.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 2 persons, 487.4ms
# Speed: 0.0ms preprocess, 487.4ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 1 person, 482.1ms
# Speed: 0.0ms preprocess, 482.1ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 2 persons, 1 kite, 480.3ms
# Speed: 0.0ms preprocess, 480.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 1 person, 488.1ms
# Speed: 7.1ms preprocess, 488.1ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 1 person, 474.2ms
# Speed: 6.2ms preprocess, 474.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 1 person, 489.3ms
# Speed: 0.0ms preprocess, 489.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 2 persons, 494.9ms
# Speed: 9.1ms preprocess, 494.9ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 2 persons, 509.1ms
# Speed: 0.0ms preprocess, 509.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 2 persons, 506.3ms
# Speed: 0.0ms preprocess, 506.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 1 person, 499.1ms
# Speed: 0.0ms preprocess, 499.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 2 persons, 506.6ms
# Speed: 0.0ms preprocess, 506.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 1 person, 488.9ms
# Speed: 6.1ms preprocess, 488.9ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 2 persons, 491.9ms
# Speed: 8.6ms preprocess, 491.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 1 person, 504.1ms
# Speed: 0.0ms preprocess, 504.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 2 persons, 1 kite, 488.5ms
# Speed: 9.1ms preprocess, 488.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 1 person, 484.9ms
# Speed: 8.1ms preprocess, 484.9ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 2 persons, 490.8ms
# Speed: 2.0ms preprocess, 490.8ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 2 persons, 494.6ms
# Speed: 5.6ms preprocess, 494.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 2 persons, 495.2ms
# Speed: 6.7ms preprocess, 495.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 2 persons, 1 cell phone, 494.7ms
# Speed: 0.0ms preprocess, 494.7ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 1 person, 526.4ms
# Speed: 8.0ms preprocess, 526.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 1
#
# 0: 480x640 2 persons, 503.9ms
# Speed: 0.0ms preprocess, 503.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 2 persons, 495.1ms
# Speed: 2.0ms preprocess, 495.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 2
#
# 0: 480x640 3 persons, 487.5ms
# Speed: 2.0ms preprocess, 487.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Humans detected: 3
